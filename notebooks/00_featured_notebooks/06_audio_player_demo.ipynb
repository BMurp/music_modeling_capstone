# %% [markdown]
# # Demonstrative "Good Vibrations" Audio Player

# %%
import sys
sys.path.insert(0, '../../')
import IPython.display as ipd
from library.notebook_api.audio_player_loader import  AudioPlayerLoader

# %%
player_loader = AudioPlayerLoader(fma_audio_data_size='small', tracks_per_genre=4)
# Out:
# /Users/murphybre/Desktop/UMichigan/Fall2024/siads699_capstone/music_modeling_capstone/notebooks/00_featured_notebooks/../../library/notebook_api/data_loader.py:25: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   self.df_filtered = self.df_files_available[self.df.label.isnull() ==False ]
# tracks in meta 29701
# tracks with files available in project_data_path:  3600
# tracks with top level genres available 29701
# tracks with genres and files (df_filtered) 3600
# /Users/murphybre/Desktop/UMichigan/Fall2024/siads699_capstone/music_modeling_capstone/notebooks/00_featured_notebooks/../../library/source_data/feature_extractor.py:130: FutureWarning: librosa.beat.tempo
# 	This function was moved to 'librosa.feature.rhythm.tempo' in librosa version 0.10.0.
# 	This alias will be removed in librosa version 1.0.
#   tempo = librosa.beat.tempo(onset_envelope=onset_env, sr=sr)[0]

# %%
ipd.display(ipd.HTML(player_loader.get_audio_browser_html()))
# Out:
#     <html>
#     <head>
#         <title>Table with Images</title>
#         <style>
#             table {{
#                 margin: auto;
#             }}
#         </style>
#     </head>
#
#     <body>
#         <table border="1">
#     <tr>
# <th>Track Id</th>
# <th>Data Source</th>
# <th>Audio Player</th>
# <th>Log Melspectrogram</th>
# <th>Feature: Tempo</th>
# <th>Actual Genre</th>
# <th>Explainable Predicted Genre</th>
# <th>Predicted Probs</th>
# <th>Unsupervised Cluster</th>
# </tr>
# <tr>
# <td>122080</td>
# <td>fma</td>
# <td><audio controls autoplay><source src="/Users/murphybre/Desktop/UMichigan/Fall2024/siads699_capstone/music_modeling_capstone/project_data_source/free_music_archive/fma_small/122/122080.mp3" type="audio/mpeg">Your browser does not support the audio element.</audio></td>
# <td><img src="data:image/png;base64,..." alt="alt image width="100" height="100"></td>
# <td>123</td>
# <td>rock</td>
# <td>rock</td>
# ...
